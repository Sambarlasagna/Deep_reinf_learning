# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# ...
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-a9o4zp20
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-a9o4zp20
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit d29756c456caadbbebc15c35893674abb2453e0d
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 37.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.3/187.3 kB 24.8 MB/s eta 0:00:00
# ...

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 41 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (524 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121689 files and directories currently installed.)
# ...

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# ...
# WARNING: gymnasium 1.2.2 does not provide the extra 'accept-rom-license'
# ...

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# | rollout/            |          |
# |    ep_len_mean      | 2.92e+03 |
# |    ep_rew_mean      | 331      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2836     |
# |    fps              | 281      |
# |    time_elapsed     | 2034     |
# |    total_timesteps  | 571840   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0464   |
# |    n_updates        | 117959   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.91e+03 |
# |    ep_rew_mean      | 329      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2840     |
# |    fps              | 281      |
# |    time_elapsed     | 2037     |
# |    total_timesteps  | 572758   |
# | train/              |          |
# ...

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# 2026-01-02 16:28:34.648513: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767371314.668321   17251 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767371314.674388   17251 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767371314.689455   17251 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
from huggingface_hub import notebook_login
notebook_login()
# !git config --global credential.helper store

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga Sambarlasagna  -f logs/
# Out:
# 2026-01-02 16:29:18.317156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767371358.337976   17450 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767371358.344209   17450 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767371358.359398   17450 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
print("Running the trained model with rendering enabled. You should see a pop-up window showing the agent playing SpaceInvaders.")
# !python -m rl_zoo3.enjoy --algo dqn --env SpaceInvadersNoFrameskip-v4 --n-timesteps 5000 --folder logs/
# Out:
# Running the trained model with rendering enabled. You should see a pop-up window showing the agent playing SpaceInvaders.
# 2026-01-02 16:33:14.248344: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767371594.267641   18489 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767371594.273527   18489 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767371594.288370   18489 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
